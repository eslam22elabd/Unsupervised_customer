# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import os
# Out:
# C:\Users\KIROO\AppData\Local\Temp\ipykernel_9144\2726316092.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("Customer Data.csv")

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
# drop this colume  (not effect in data)
df.drop(['CUST_ID'],axis=1,inplace=True)

# %%
# drop null from this colums
df.dropna(inplace=True,axis=0)
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# some visulaization
X=sns.PairGrid(df)
X=X.map(plt.scatter)
plt.show()

# %%
X=df

# %%
df.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.310140   0.176083
# BALANCE_FREQUENCY                 0.310140           1.000000   0.122635
# PURCHASES                         0.176083           0.122635   1.000000
# ONEOFF_PURCHASES                  0.159985           0.095254   0.916780
# INSTALLMENTS_PURCHASES            0.122109           0.114739   0.679259
# CASH_ADVANCE                      0.495586           0.089036  -0.053760
# PURCHASES_FREQUENCY              -0.088459           0.228158   0.393000
# ONEOFF_PURCHASES_FREQUENCY        0.063832           0.187467   0.497384
# PURCHASES_INSTALLMENTS_FREQUENCY -0.069582           0.184159   0.316025
# CASH_ADVANCE_FREQUENCY            0.445307           0.181132  -0.124863
# CASH_ADVANCE_TRX                  0.382388           0.133265  -0.070277
# PURCHASES_TRX                     0.147887           0.183095   0.688732
# ...

# %%
# to see correlation
sns.clustermap(X.corr(), vmin = -1, vmax = 1, annot = True)

# %%
# too see outlayers
sns.boxplot(data = X, width = 0.8)
# Out:
# <Axes: >

# %%
# to scale data
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
# to see outlayer using z_score
from scipy import stats
z_scores = np.abs(stats.zscore(X))
threshold = 4
outliers = np.where(z_scores > threshold)

# %%
# to delete outlayers
mask = (z_scores<threshold).all(axis=1)
X=X[mask]



# تصفية القيم التي تتجاوز العتبة
# filtered_data = [X[i] for i in range(len(X)) if z_scores[i] < threshold]

# print("البيانات الأصلية:", X)
# print("البيانات بعد إزالة القيم الخارجة:", filtered_data)
# X=X[filtered_data]

# %%
# to اختزال العواميد
pca = PCA(n_components = 1)
X = pca.fit_transform(X)

# %%
# using k_means for modling
for i in range(1, 17):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)

# %%
y_kmeans = kmeans.fit_predict(X)
# Calculate inertia
inertia = kmeans.inertia_

# Calculate Silhouette Score
silhouette_avg = silhouette_score(X, y_kmeans)

print(f'Inertia: {inertia}')
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Inertia: 171.04612762486425
# Silhouette Score: 0.5245265984920648
